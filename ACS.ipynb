# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
raw_acs=pd.read_csv("..\\..\\Downloads\\Spring_Invitational_2024_data\\Datathon Data\\acs_5yr_est_selected_economic_characteristics_2010-2022.csv")
raw_acs['header']=''

# %%
raw_acs
# Out:
#                               Label (Grouping)  \
# 0                            EMPLOYMENT STATUS
# 1                 Population 16 years and over
# 2                               In labor force
# 3                         Civilian labor force
# 4                                     Employed
# ...                                        ...
# 98015                        18 years and over
# 98016                           18 to 64 years
# 98017                        65 years and over
# 98018                       People in families
# 98019  Unrelated individuals 15 years and over
#
#                                                 Category        State  \
# 0                                                 Header      Alabama
# 1                                      EMPLOYMENT STATUS      Alabama
# 2                                      EMPLOYMENT STATUS      Alabama
# 3                                      EMPLOYMENT STATUS      Alabama
# 4                                      EMPLOYMENT STATUS      Alabama
# ...                                                  ...          ...
# 98015  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...  Puerto Rico
# 98016  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...  Puerto Rico
# 98017  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...  Puerto Rico
# 98018  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...  Puerto Rico
# 98019  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...  Puerto Rico
#
#         Estimate Margin of Error    Percent Percent Margin of Error  Year  \
# 0            NaN             NaN        NaN                     NaN  2010
# 1      3,714,504          ±1,588  3,714,504                     (X)  2010
# 2      2,246,848          ±5,576      60.5%                    ±0.1  2010
# 3      2,230,879          ±5,531      60.1%                    ±0.1  2010
# 4      2,036,867          ±5,904      54.8%                    ±0.2  2010
# ...          ...             ...        ...                     ...   ...
# 98015        (X)             (X)      39.7%                    ±0.4  2021
# 98016        (X)             (X)      40.1%                    ±0.4  2021
# 98017        (X)             (X)      38.5%                    ±0.5  2021
# 98018        (X)             (X)      40.0%                    ±0.4  2021
# 98019        (X)             (X)      55.3%                    ±0.4  2021
#
#       header
# 0
# 1
# 2
# 3
# 4
# ...      ...
# 98015
# 98016
# 98017
# 98018
# 98019
#
# [98020 rows x 9 columns]

# %%
#gross cell, worst practices, bad code to clean bad data
header_list=[]
replaced_count=0
econ_count=0
for i in tqdm(range(raw_acs.shape[0])):
    #see if the label has an indendentation indicating its a sub level
    if '\xa0' not in raw_acs.iloc[i,0]:
        header_list=[raw_acs.iloc[i,0]]
        #if it doesn't keep the level to use as the top level header
    else:
        #4 tabs per sublevel
        subheader_level=raw_acs.iloc[i,0].count(u'\xa0')//4
        #get all of the appropriate subheaders and put them in the header column for that row
        raw_acs.iloc[i,8]='_'.join(header_list[0:subheader_level])
        #update the headerlist incase this level has a subheader
        header_list=header_list[:]+[raw_acs.iloc[i,0].replace(u'\xa0', u'')]
        
    #see if we are missing a percent but have an estimate for numeric quantities that aren't population estimates

    if raw_acs.iloc[i,5]=='(X)' :
        raw_acs.iloc[i,5]=raw_acs.iloc[i,3]
        replaced_count+=1
    
    #each year income number as reported as year 20XY adjusted dollars, so to fix this we are gonna lump all together and deal with inflation later lol
    if 'IN 20' in raw_acs.iloc[i,1]:
        raw_acs.iloc[i,1]='INCOME AND BENEFITS (Not inflation Adjusted)'
        if 'Total households' in raw_acs.iloc[i,0] or  'Families' in raw_acs.iloc[i,0]:
            econ_count+=1
            raw_acs.iloc[i+1:i+11,8]='by '+raw_acs.iloc[i,0].replace(u'\xa0', u'')
    #sometimes the income in YEAR Dollars gets stuck in the header section and we dont want that 
    if 'IN 20' in  raw_acs.iloc[i,8]:
        raw_acs.iloc[i,8]=''
econ_count
# Out:
# 100%|██████████| 98020/98020 [00:28<00:00, 3449.07it/s]
# 1352

# %%
acs=raw_acs
print(acs.shape[0])
#get rid of missing values
acs.replace(to_replace='(X)',value=np.nan,inplace=True)
#drop useless rows
acs=acs[acs['Category']!='Header']
acs['header']=pd.Series.str(acs['header']).replace("$200,000 or more", u'')
#combine the headers to ensure unique column names
acs['Label (Grouping)']=pd.Series.str(acs['Label (Grouping)']).replace(u'\xa0', u'')
acs.loc[:,'full_label']=acs['Category']+'_'+acs['header']+'_'+acs['Label (Grouping)']
#only get the columns we need
acs=acs.iloc[:,[2,3,5,7,9]]
acs=acs.dropna()
print(acs.shape[0])
acs
# Out:
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_280\324354553.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   acs['header']=pd.Series.str(acs['header']).replace("$200,000 or more", u'')
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_280\324354553.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   acs['Label (Grouping)']=pd.Series.str(acs['Label (Grouping)']).replace(u'\xa0', u'')
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_280\324354553.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   acs.loc[:,'full_label']=acs['Category']+'_'+acs['header']+'_'+acs['Label (Grouping)']
# 98020
# 76596
#              State   Estimate    Percent  Year  \
# 1          Alabama  3,714,504  3,714,504  2010
# 2          Alabama  2,246,848      60.5%  2010
# 3          Alabama  2,230,879      60.1%  2010
# 4          Alabama  2,036,867      54.8%  2010
# 5          Alabama    194,012       5.2%  2010
# ...            ...        ...        ...   ...
# 97995  Puerto Rico    772,116    772,116  2021
# 97996  Puerto Rico    713,557      92.4%  2021
# 97997  Puerto Rico    206,789      26.8%  2021
# 97998  Puerto Rico    535,314      69.3%  2021
# 97999  Puerto Rico     58,559       7.6%  2021
#
#                                               full_label
# 1        EMPLOYMENT STATUS__Population 16 years and over
# 2      EMPLOYMENT STATUS_Population 16 years and over...
# 3      EMPLOYMENT STATUS_Population 16 years and over...
# 4      EMPLOYMENT STATUS_Population 16 years and over...
# 5      EMPLOYMENT STATUS_Population 16 years and over...
# ...                                                  ...
# 97995  HEALTH INSURANCE COVERAGE_Civilian noninstitut...
# 97996  HEALTH INSURANCE COVERAGE_Civilian noninstitut...
# 97997  HEALTH INSURANCE COVERAGE_Civilian noninstitut...
# 97998  HEALTH INSURANCE COVERAGE_Civilian noninstitut...
# 97999  HEALTH INSURANCE COVERAGE_Civilian noninstitut...
#
# [76596 rows x 5 columns]

# %%
acs_by_state={state:acs[acs['State']==state] for state in set(acs['State'])}

# %%
acs.shape[0]==acs.dropna().shape[0]
# Out:
# True

# %%
al=acs_by_state['Alabama']
al[al['Year']==2010].to_csv('test al data.csv')

# %%
len(set(acs['full_label'])),set(acs['full_label'])
# Out:
# (186,
#  {'CLASS OF WORKER_Civilian employed population 16 years and over_Government workers',
#   'CLASS OF WORKER_Civilian employed population 16 years and over_Private wage and salary workers',
#   'CLASS OF WORKER_Civilian employed population 16 years and over_Private wage and salary workers_Government workers',
#   'CLASS OF WORKER_Civilian employed population 16 years and over_Private wage and salary workers_Self-employed in own not incorporated business workers',
#   'CLASS OF WORKER_Civilian employed population 16 years and over_Private wage and salary workers_Unpaid family workers',
#   'CLASS OF WORKER_Civilian employed population 16 years and over_Self-employed in own not incorporated business workers',
#   'CLASS OF WORKER_Civilian employed population 16 years and over_Unpaid family workers',
#   'CLASS OF WORKER__Civilian employed population 16 years and over',
#   'COMMUTING TO WORK_Workers 16 years and over_Car, truck, or van -- carpooled',
#   'COMMUTING TO WORK_Workers 16 years and over_Car, truck, or van -- drove alone',
#   'COMMUTING TO WORK_Workers 16 years and over_Car, truck, or van -- drove alone_Car, truck, or van -- carpooled',
#   'COMMUTING TO WORK_Workers 16 years and over_Car, truck, or van -- drove alone_Mean travel time to work (minutes)',
#   'COMMUTING TO WORK_Workers 16 years and over_Car, truck, or van -- drove alone_Other means',
#   'COMMUTING TO WORK_Workers 16 years and over_Car, truck, or van -- drove alone_Public transportation (excluding taxicab)',
#   'COMMUTING TO WORK_Workers 16 years and over_Car, truck, or van -- drove alone_Walked',
#   'COMMUTING TO WORK_Workers 16 years and over_Car, truck, or van -- drove alone_Worked at home',
#   'COMMUTING TO WORK_Workers 16 years and over_Car, truck, or van -- drove alone_Worked from home',
#   'COMMUTING TO WORK_Workers 16 years and over_Mean travel time to work (minutes)',
#   'COMMUTING TO WORK_Workers 16 years and over_Other means',
#   'COMMUTING TO WORK_Workers 16 years and over_Public transportation (excluding taxicab)',
#   'COMMUTING TO WORK_Workers 16 years and over_Walked',
#   'COMMUTING TO WORK_Workers 16 years and over_Worked at home',
#   'COMMUTING TO WORK__Workers 16 years and over',
#   'EMPLOYMENT STATUS_Females 16 years and over_In labor force',
#   'EMPLOYMENT STATUS_Females 16 years and over_In labor force_Civilian labor force',
#   'EMPLOYMENT STATUS_Females 16 years and over_In labor force_Civilian labor force_Employed',
#   'EMPLOYMENT STATUS_Own children 6 to 17 years_All parents in family in labor force',
#   'EMPLOYMENT STATUS_Own children of the householder 6 to 17 years_All parents in family in labor force',
#   'EMPLOYMENT STATUS_Own children of the householder under 6 years_All parents in family in labor force',
#   'EMPLOYMENT STATUS_Own children under 6 years_All parents in family in labor force',
#   'EMPLOYMENT STATUS_Population 16 years and over_Civilian labor force',
#   'EMPLOYMENT STATUS_Population 16 years and over_In labor force',
#   'EMPLOYMENT STATUS_Population 16 years and over_In labor force_Armed Forces',
#   'EMPLOYMENT STATUS_Population 16 years and over_In labor force_Civilian labor force',
#   'EMPLOYMENT STATUS_Population 16 years and over_In labor force_Civilian labor force_Armed Forces',
#   'EMPLOYMENT STATUS_Population 16 years and over_In labor force_Civilian labor force_Employed',
#   'EMPLOYMENT STATUS_Population 16 years and over_In labor force_Civilian labor force_Employed_Unemployed',
#   'EMPLOYMENT STATUS_Population 16 years and over_In labor force_Civilian labor force_Unemployed',
#   'EMPLOYMENT STATUS_Population 16 years and over_In labor force_Not in labor force',
#   'EMPLOYMENT STATUS_Population 16 years and over_Not in labor force',
#   'EMPLOYMENT STATUS__Females 16 years and over',
#   'EMPLOYMENT STATUS__Own children 6 to 17 years',
#   'EMPLOYMENT STATUS__Own children of the householder 6 to 17 years',
#   'EMPLOYMENT STATUS__Own children of the householder under 6 years',
#   'EMPLOYMENT STATUS__Own children under 6 years',
#   'EMPLOYMENT STATUS__Population 16 years and over',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_Employed:',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_Employed:_No health insurance coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_Employed:_Unemployed:',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_Employed:_With health insurance coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_Employed:_With health insurance coverage_No health insurance coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_Employed:_With health insurance coverage_With health insurance coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_Employed:_With health insurance coverage_With private health insurance',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_Employed:_With health insurance coverage_With private health insurance_With private health insurance',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_Employed:_With health insurance coverage_With private health insurance_With public coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_Employed:_With health insurance coverage_With public coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_Employed:_With private health insurance',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_Employed:_With public coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_No health insurance coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_Not in labor force:',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_Unemployed:',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_In labor force:_With health insurance coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 18 to 64 years_Not in labor force:',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_No health insurance coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_Unemployed:',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_With health insurance coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_With health insurance coverage_No health insurance coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_With health insurance coverage_With health insurance coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_With health insurance coverage_With private health insurance',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_With health insurance coverage_With private health insurance_With private health insurance',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_With health insurance coverage_With private health insurance_With public coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_With health insurance coverage_With public coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Not in labor force:',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population under 18 years_No health insurance coverage',
#   'HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population under 19 years_No health insurance coverage',
#   'HEALTH INSURANCE COVERAGE_HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population',
#   'HEALTH INSURANCE COVERAGE_HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population_No health insurance coverage',
#   'HEALTH INSURANCE COVERAGE_HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population_With health insurance coverage',
#   'HEALTH INSURANCE COVERAGE_HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population_With health insurance coverage_With private health insurance',
#   'HEALTH INSURANCE COVERAGE_HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population_With health insurance coverage_With public coverage',
#   'HEALTH INSURANCE COVERAGE_HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population_With private health insurance',
#   'HEALTH INSURANCE COVERAGE_HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population_With public coverage',
#   'HEALTH INSURANCE COVERAGE_HEALTH INSURANCE COVERAGE_No health insurance coverage',
#   'HEALTH INSURANCE COVERAGE_HEALTH INSURANCE COVERAGE_With health insurance coverage',
#   'HEALTH INSURANCE COVERAGE__Civilian noninstitutionalized population 18 to 64 years',
#   'HEALTH INSURANCE COVERAGE__Civilian noninstitutionalized population 19 to 64 years',
#   'HEALTH INSURANCE COVERAGE__Civilian noninstitutionalized population under 18 years',
#   'HEALTH INSURANCE COVERAGE__Civilian noninstitutionalized population under 19 years',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_With Food Stamp/SNAP benefits in the past 12 months_Families',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Mean family income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Mean household income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Mean nonfamily income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median earnings for female full-time, year-round workers (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median earnings for male full-time, year-round workers (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median earnings for workers (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median family income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median family income (dollars)_Mean family income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median family income (dollars)_Mean nonfamily income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median family income (dollars)_Median nonfamily income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median family income (dollars)_Per capita income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_Mean Social Security income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_Mean Supplemental Security Income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_Mean cash public assistance income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_Mean earnings (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_Mean household income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_Mean household income (dollars)_Mean Social Security income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_Mean household income (dollars)_Mean Supplemental Security Income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_Mean household income (dollars)_Mean cash public assistance income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_Mean household income (dollars)_Mean earnings (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_Mean household income (dollars)_Mean retirement income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_Mean retirement income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_With Social Security',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_With Supplemental Security Income',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_With cash public assistance income',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_With earnings',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)_With retirement income',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Median nonfamily income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Nonfamily households',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Per capita income (dollars)',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__Total households',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__With Food Stamp/SNAP benefits in the past 12 months',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__With Social Security',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__With Supplemental Security Income',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__With cash public assistance income',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__With earnings',
#   'INCOME AND BENEFITS (Not inflation Adjusted)__With retirement income',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Families_$10,000 to $14,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Families_$100,000 to $149,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Families_$15,000 to $24,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Families_$150,000 to $199,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Families_$200,000 or more',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Families_$25,000 to $34,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Families_$35,000 to $49,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Families_$50,000 to $74,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Families_$75,000 to $99,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Families_Less than $10,000',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Total households_$10,000 to $14,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Total households_$100,000 to $149,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Total households_$15,000 to $24,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Total households_$150,000 to $199,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Total households_$200,000 or more',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Total households_$25,000 to $34,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Total households_$35,000 to $49,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Total households_$50,000 to $74,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Total households_$75,000 to $99,999',
#   'INCOME AND BENEFITS (Not inflation Adjusted)_by Total households_Less than $10,000',
#   'INDUSTRY_Civilian employed population 16 years and over_Agriculture, forestry, fishing and hunting, and mining',
#   'INDUSTRY_Civilian employed population 16 years and over_Agriculture, forestry, fishing and hunting, and mining_Arts, entertainment, and recreation, and accommodation and food services',
#   'INDUSTRY_Civilian employed population 16 years and over_Agriculture, forestry, fishing and hunting, and mining_Construction',
#   'INDUSTRY_Civilian employed population 16 years and over_Agriculture, forestry, fishing and hunting, and mining_Educational services, and health care and social assistance',
#   'INDUSTRY_Civilian employed population 16 years and over_Agriculture, forestry, fishing and hunting, and mining_Finance and insurance, and real estate and rental and leasing',
#   'INDUSTRY_Civilian employed population 16 years and over_Agriculture, forestry, fishing and hunting, and mining_Information',
#   'INDUSTRY_Civilian employed population 16 years and over_Agriculture, forestry, fishing and hunting, and mining_Manufacturing',
#   'INDUSTRY_Civilian employed population 16 years and over_Agriculture, forestry, fishing and hunting, and mining_Other services, except public administration',
#   'INDUSTRY_Civilian employed population 16 years and over_Agriculture, forestry, fishing and hunting, and mining_Professional, scientific, and management, and administrative and waste management services',
#   'INDUSTRY_Civilian employed population 16 years and over_Agriculture, forestry, fishing and hunting, and mining_Public administration',
#   'INDUSTRY_Civilian employed population 16 years and over_Agriculture, forestry, fishing and hunting, and mining_Retail trade',
#   'INDUSTRY_Civilian employed population 16 years and over_Agriculture, forestry, fishing and hunting, and mining_Transportation and warehousing, and utilities',
#   'INDUSTRY_Civilian employed population 16 years and over_Agriculture, forestry, fishing and hunting, and mining_Wholesale trade',
#   'INDUSTRY_Civilian employed population 16 years and over_Arts, entertainment, and recreation, and accommodation and food services',
#   'INDUSTRY_Civilian employed population 16 years and over_Construction',
#   'INDUSTRY_Civilian employed population 16 years and over_Educational services, and health care and social assistance',
#   'INDUSTRY_Civilian employed population 16 years and over_Finance and insurance, and real estate and rental and leasing',
#   'INDUSTRY_Civilian employed population 16 years and over_Information',
#   'INDUSTRY_Civilian employed population 16 years and over_Manufacturing',
#   'INDUSTRY_Civilian employed population 16 years and over_Other services, except public administration',
#   'INDUSTRY_Civilian employed population 16 years and over_Professional, scientific, and management, and administrative and waste management services',
#   'INDUSTRY_Civilian employed population 16 years and over_Public administration',
#   'INDUSTRY_Civilian employed population 16 years and over_Retail trade',
#   'INDUSTRY_Civilian employed population 16 years and over_Transportation and warehousing, and utilities',
#   'INDUSTRY_Civilian employed population 16 years and over_Wholesale trade',
#   'INDUSTRY__Civilian employed population 16 years and over',
#   'OCCUPATION_Civilian employed population 16 years and over_Management, business, science, and arts occupations',
#   'OCCUPATION_Civilian employed population 16 years and over_Management, business, science, and arts occupations_Natural resources, construction, and maintenance occupations',
#   'OCCUPATION_Civilian employed population 16 years and over_Management, business, science, and arts occupations_Production, transportation, and material moving occupations',
#   'OCCUPATION_Civilian employed population 16 years and over_Management, business, science, and arts occupations_Sales and office occupations',
#   'OCCUPATION_Civilian employed population 16 years and over_Management, business, science, and arts occupations_Service occupations',
#   'OCCUPATION_Civilian employed population 16 years and over_Natural resources, construction, and maintenance occupations',
#   'OCCUPATION_Civilian employed population 16 years and over_Production, transportation, and material moving occupations',
#   'OCCUPATION_Civilian employed population 16 years and over_Sales and office occupations',
#   'OCCUPATION_Civilian employed population 16 years and over_Service occupations',
#   'OCCUPATION__Civilian employed population 16 years and over'})

# %%
#make it not ugly 
acs_by_col=pd.DataFrame(index=[state+'_'+str(year) for state in acs['State'].unique() for year in range(2010,2023)],columns=['State','Year','YOY_Change_in_Median_household_income']+list(acs['full_label'].unique()))
for state in tqdm(acs['State'].unique()):
    for year in range(2010,2023):
        state_data=acs_by_state[state][acs_by_state[state]['Year']==year]
        acs_by_col.loc[state+'_'+str(year),'State']=state
        acs_by_col.loc[state+'_'+str(year),'Year']=year
        for col in state_data['full_label'].unique():
            acs_by_col.loc[state+'_'+str(year),col]=state_data[state_data['full_label']==col]['Percent'].values
        
acs_by_col["INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)"]=[int(str(i).replace(u',', u'')) for i in acs_by_col["INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)"].values]
# Out:
# 100%|██████████| 52/52 [00:21<00:00,  2.38it/s]

# %%
for state in tqdm(acs['State'].unique()):
    for year in range(2010,2023):
        if year!=2010:
            curr_med_income=acs_by_col.loc[state+'_'+str(year),"INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)"]
            prev_med_income=acs_by_col.loc[state+'_'+str(year-1),"INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)"]
            acs_by_col.loc[state+'_'+str(year),'YOY_Change_in_Median_household_income']=(curr_med_income-prev_med_income)/prev_med_income
# Out:
# 100%|██████████| 52/52 [00:00<00:00, 666.69it/s]

# %%
#isn't it beautiful 
acs_by_col.to_csv('acs_better_formating.csv')
acs_by_col
# Out:
#                         State  Year YOY_Change_in_Median_household_income  \
# Alabama_2010          Alabama  2010                                   NaN
# Alabama_2011          Alabama  2011                               0.02027
# Alabama_2012          Alabama  2012                              0.005264
# Alabama_2013          Alabama  2013                              0.002155
# Alabama_2014          Alabama  2014                              0.005965
# ...                       ...   ...                                   ...
# Puerto Rico_2018  Puerto Rico  2018                              0.019772
# Puerto Rico_2019  Puerto Rico  2019                              0.018496
# Puerto Rico_2020  Puerto Rico  2020                              0.025269
# Puerto Rico_2021  Puerto Rico  2021                              0.043166
# Puerto Rico_2022  Puerto Rico  2022                              0.092639
#
#                  EMPLOYMENT STATUS__Population 16 years and over  \
# Alabama_2010                                           3,714,504
# Alabama_2011                                           3,748,844
# Alabama_2012                                           3,779,457
# Alabama_2013                                           3,806,434
# Alabama_2014                                           3,828,799
# ...                                                          ...
# Puerto Rico_2018                                       2,793,000
# Puerto Rico_2019                                       2,759,025
# Puerto Rico_2020                                       2,728,839
# Puerto Rico_2021                                       2,797,936
# Puerto Rico_2022                                       2,785,909
#
#                  EMPLOYMENT STATUS_Population 16 years and over_In labor force  \
# Alabama_2010                                                  60.5%
# Alabama_2011                                                  60.3%
# Alabama_2012                                                  59.9%
# Alabama_2013                                                  59.4%
# Alabama_2014                                                  58.8%
# ...                                                             ...
# Puerto Rico_2018                                              44.4%
# Puerto Rico_2019                                              44.5%
# Puerto Rico_2020                                              44.4%
# Puerto Rico_2021                                              44.3%
# Puerto Rico_2022                                              44.9%
#
#                  EMPLOYMENT STATUS_Population 16 years and over_In labor force_Civilian labor force  \
# Alabama_2010                                                  60.1%
# Alabama_2011                                                  59.8%
# Alabama_2012                                                  59.5%
# Alabama_2013                                                  59.0%
# Alabama_2014                                                  58.5%
# ...                                                             ...
# Puerto Rico_2018                                              44.3%
# Puerto Rico_2019                                              44.4%
# Puerto Rico_2020                                              44.3%
# Puerto Rico_2021                                              44.2%
# Puerto Rico_2022                                              44.8%
#
#                  EMPLOYMENT STATUS_Population 16 years and over_In labor force_Civilian labor force_Employed  \
# Alabama_2010                                                  54.8%
# Alabama_2011                                                  54.1%
# Alabama_2012                                                  53.4%
# Alabama_2013                                                  52.6%
# Alabama_2014                                                  52.5%
# ...                                                             ...
# Puerto Rico_2018                                              36.8%
# Puerto Rico_2019                                              37.3%
# Puerto Rico_2020                                              37.6%
# Puerto Rico_2021                                              37.7%
# Puerto Rico_2022                                              38.8%
#
#                  EMPLOYMENT STATUS_Population 16 years and over_In labor force_Civilian labor force_Unemployed  \
# Alabama_2010                                                   5.2%
# Alabama_2011                                                   5.7%
# Alabama_2012                                                   6.1%
# Alabama_2013                                                    NaN
# Alabama_2014                                                    NaN
# ...                                                             ...
# Puerto Rico_2018                                                NaN
# Puerto Rico_2019                                                NaN
# Puerto Rico_2020                                                NaN
# Puerto Rico_2021                                                NaN
# Puerto Rico_2022                                                NaN
#
#                  EMPLOYMENT STATUS_Population 16 years and over_In labor force_Armed Forces  \
# Alabama_2010                                                   0.4%
# Alabama_2011                                                   0.4%
# Alabama_2012                                                   0.4%
# Alabama_2013                                                    NaN
# Alabama_2014                                                    NaN
# ...                                                             ...
# Puerto Rico_2018                                                NaN
# Puerto Rico_2019                                                NaN
# Puerto Rico_2020                                                NaN
# Puerto Rico_2021                                                NaN
# Puerto Rico_2022                                                NaN
#
#                  EMPLOYMENT STATUS_Population 16 years and over_Not in labor force  \
# Alabama_2010                                                  39.5%
# Alabama_2011                                                  39.7%
# Alabama_2012                                                  40.1%
# Alabama_2013                                                    NaN
# Alabama_2014                                                    NaN
# ...                                                             ...
# Puerto Rico_2018                                                NaN
# Puerto Rico_2019                                                NaN
# Puerto Rico_2020                                                NaN
# Puerto Rico_2021                                                NaN
# Puerto Rico_2022                                                NaN
#
#                   ...  \
# Alabama_2010      ...
# Alabama_2011      ...
# Alabama_2012      ...
# Alabama_2013      ...
# Alabama_2014      ...
# ...               ...
# Puerto Rico_2018  ...
# Puerto Rico_2019  ...
# Puerto Rico_2020  ...
# Puerto Rico_2021  ...
# Puerto Rico_2022  ...
#
#                  HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_With health insurance coverage_With private health insurance  \
# Alabama_2010                                                    NaN
# Alabama_2011                                                    NaN
# Alabama_2012                                                    NaN
# Alabama_2013                                                    NaN
# Alabama_2014                                                    NaN
# ...                                                             ...
# Puerto Rico_2018                                     [61.6%, 26.8%]
# Puerto Rico_2019                                     [61.1%, 26.5%]
# Puerto Rico_2020                                     [60.8%, 26.8%]
# Puerto Rico_2021                                     [60.1%, 26.8%]
# Puerto Rico_2022                                     [59.8%, 27.1%]
#
#                  HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_With health insurance coverage_With private health insurance_With public coverage  \
# Alabama_2010                                                    NaN
# Alabama_2011                                                    NaN
# Alabama_2012                                                    NaN
# Alabama_2013                                                    NaN
# Alabama_2014                                                    NaN
# ...                                                             ...
# Puerto Rico_2018                                     [29.8%, 71.1%]
# Puerto Rico_2019                                     [29.6%, 69.9%]
# Puerto Rico_2020                                     [29.4%, 69.1%]
# Puerto Rico_2021                                     [30.1%, 68.4%]
# Puerto Rico_2022                                     [31.1%, 68.0%]
#
#                  HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_With health insurance coverage_No health insurance coverage  \
# Alabama_2010                                                    NaN
# Alabama_2011                                                    NaN
# Alabama_2012                                                    NaN
# Alabama_2013                                                    NaN
# Alabama_2014                                                    NaN
# ...                                                             ...
# Puerto Rico_2018                                     [10.6%, 12.7%]
# Puerto Rico_2019                                     [11.1%, 13.8%]
# Puerto Rico_2020                                     [11.5%, 14.5%]
# Puerto Rico_2021                                     [11.4%, 14.3%]
# Puerto Rico_2022                                     [10.7%, 14.2%]
#
#                  HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_Unemployed:  \
# Alabama_2010                                                    NaN
# Alabama_2011                                                    NaN
# Alabama_2012                                                    NaN
# Alabama_2013                                                    NaN
# Alabama_2014                                                    NaN
# ...                                                             ...
# Puerto Rico_2018                                            198,555
# Puerto Rico_2019                                            186,849
# Puerto Rico_2020                                            173,231
# Puerto Rico_2021                                            171,430
# Puerto Rico_2022                                            157,279
#
#                  HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_With health insurance coverage_With health insurance coverage  \
# Alabama_2010                                                    NaN
# Alabama_2011                                                    NaN
# Alabama_2012                                                    NaN
# Alabama_2013                                                    NaN
# Alabama_2014                                                    NaN
# ...                                                             ...
# Puerto Rico_2018                                              87.3%
# Puerto Rico_2019                                              86.2%
# Puerto Rico_2020                                              85.5%
# Puerto Rico_2021                                              85.7%
# Puerto Rico_2022                                              85.8%
#
#                  HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_With health insurance coverage_With private health insurance_With private health insurance  \
# Alabama_2010                                                    NaN
# Alabama_2011                                                    NaN
# Alabama_2012                                                    NaN
# Alabama_2013                                                    NaN
# Alabama_2014                                                    NaN
# ...                                                             ...
# Puerto Rico_2018                                              17.3%
# Puerto Rico_2019                                              17.4%
# Puerto Rico_2020                                              17.6%
# Puerto Rico_2021                                              18.5%
# Puerto Rico_2022                                              18.9%
#
#                  HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Not in labor force:  \
# Alabama_2010                                                    NaN
# Alabama_2011                                                    NaN
# Alabama_2012                                                    NaN
# Alabama_2013                                                    NaN
# Alabama_2014                                                    NaN
# ...                                                             ...
# Puerto Rico_2018                                            809,968
# Puerto Rico_2019                                            782,851
# Puerto Rico_2020                                            764,101
# Puerto Rico_2021                                            772,116
# Puerto Rico_2022                                            738,358
#
#                  HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_With health insurance coverage_With public coverage  \
# Alabama_2010                                                    NaN
# Alabama_2011                                                    NaN
# Alabama_2012                                                    NaN
# Alabama_2013                                                    NaN
# Alabama_2014                                                    NaN
# ...                                                             ...
# Puerto Rico_2018                                              70.6%
# Puerto Rico_2019                                              70.5%
# Puerto Rico_2020                                              69.7%
# Puerto Rico_2021                                              69.3%
# Puerto Rico_2022                                              69.4%
#
#                  HEALTH INSURANCE COVERAGE_Civilian noninstitutionalized population 19 to 64 years_In labor force:_Employed:_No health insurance coverage  \
# Alabama_2010                                                    NaN
# Alabama_2011                                                    NaN
# Alabama_2012                                                    NaN
# Alabama_2013                                                    NaN
# Alabama_2014                                                    NaN
# ...                                                             ...
# Puerto Rico_2018                                               6.5%
# Puerto Rico_2019                                               6.9%
# Puerto Rico_2020                                               7.3%
# Puerto Rico_2021                                               7.6%
# Puerto Rico_2022                                               7.1%
#
#                  COMMUTING TO WORK_Workers 16 years and over_Car, truck, or van -- drove alone_Worked from home
# Alabama_2010                                                    NaN
# Alabama_2011                                                    NaN
# Alabama_2012                                                    NaN
# Alabama_2013                                                    NaN
# Alabama_2014                                                    NaN
# ...                                                             ...
# Puerto Rico_2018                                                NaN
# Puerto Rico_2019                                               2.3%
# Puerto Rico_2020                                               3.1%
# Puerto Rico_2021                                               4.2%
# Puerto Rico_2022                                               4.8%
#
# [676 rows x 189 columns]

# %%
states=list(set(acs_by_col['State']))
states.remove('Puerto Rico')
states.sort()
states
col="INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)"
avg_state_median_income_by_year=[ acs_by_col[(acs_by_col['Year']==year)][col].mean() for year in range(2010,2023)]
avg_state_median_income_by_year
# Out:
# [51142.057692307695,
#  52282.846153846156,
#  52672.903846153844,
#  52878.230769230766,
#  53468.78846153846,
#  53957.519230769234,
#  55330.57692307692,
#  57496.82692307692,
#  59842.692307692305,
#  62279.42307692308,
#  64199.269230769234,
#  67969.76923076923,
#  73828.05769230769]

# %%
oil_data_by_year=()
for year in range(2011,2023):
    data=acs_by_col[acs_by_col['Year']==year]
    x=data['INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)'][:51]
    y=data['YOY_Change_in_Median_household_income'][:51]*100
    fig = plt.figure(figsize=[12.8,7.2],dpi=120)
    ax1 = fig.add_subplot(111)
    ax1.set_ylabel('YOY Percent Change in Income')
    ax1.set_xlabel('Median Household Income')
    ax1.set_title(str(year))
    ax1.scatter(x=x,y=y)
    for i in range(len(states)):
        ax1.text(x.iloc[i],y.iloc[i],states[i])
    plt.show()

# %%
states=list(set(acs_by_col['State']))
states.remove('Puerto Rico')
states.sort()
states
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %%
col="INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars)"

test=acs_by_col
test[col]=[int(str(i).replace(u',', u'')) for i in test[col].values]
#pd.Series.str(test[col]).replace(u',', u'')

test[col]
# Out:
# Alabama_2010        42081
# Alabama_2011        42934
# Alabama_2012        43160
# Alabama_2013        43253
# Alabama_2014        43511
#                     ...
# Puerto Rico_2018    20166
# Puerto Rico_2019    20539
# Puerto Rico_2020    21058
# Puerto Rico_2021    21967
# Puerto Rico_2022    24002
# Name: INCOME AND BENEFITS (Not inflation Adjusted)__Median household income (dollars), Length: 676, dtype: int64
