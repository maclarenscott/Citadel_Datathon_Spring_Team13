# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
commods=pd.read_csv("Downloads\\Spring_Invitational_2024_data\\Datathon Data\\all_commodities.csv")
commods.loc[:,'Date_Time']=pd.to_datetime(commods.loc[:,'Date_Time'])
commods=commods.dropna()
commods.loc[:,'Daily Return']=commods.loc[:,'Value'].pct_change()
commods=commods.dropna()
commods
# Out:
#                  Date_Time  Value                         Commodity  \
# 1      2024-01-22 00:00:00   2.35  Henry Hub Natural Gas Spot Price
# 2      2024-01-19 00:00:00   2.70  Henry Hub Natural Gas Spot Price
# 3      2024-01-18 00:00:00   2.88  Henry Hub Natural Gas Spot Price
# 4      2024-01-17 00:00:00   2.86  Henry Hub Natural Gas Spot Price
# 5      2024-01-16 00:00:00   3.25  Henry Hub Natural Gas Spot Price
# ...                    ...    ...                               ...
# 26553  1987-05-26 00:00:00  18.63                   Brent Crude Oil
# 26554  1987-05-25 00:00:00  18.60                   Brent Crude Oil
# 26555  1987-05-22 00:00:00  18.55                   Brent Crude Oil
# 26556  1987-05-21 00:00:00  18.45                   Brent Crude Oil
# 26557  1987-05-20 00:00:00  18.63                   Brent Crude Oil
#
#       Commodity_Simple                     Unit  Daily Return
# 1          NATURAL_GAS  Dollars per Million BTU      0.093023
# 2          NATURAL_GAS  Dollars per Million BTU      0.148936
# 3          NATURAL_GAS  Dollars per Million BTU      0.066667
# 4          NATURAL_GAS  Dollars per Million BTU     -0.006944
# 5          NATURAL_GAS  Dollars per Million BTU      0.136364
# ...                ...                      ...           ...
# 26553            BRENT       Dollars per Barrel      0.001613
# 26554            BRENT       Dollars per Barrel     -0.001610
# 26555            BRENT       Dollars per Barrel     -0.002688
# 26556            BRENT       Dollars per Barrel     -0.005391
# 26557            BRENT       Dollars per Barrel      0.009756
#
# [25690 rows x 6 columns]

# %%
set(commods['Commodity'])
# Out:
# {'Brent Crude Oil',
#  'Henry Hub Natural Gas Spot Price',
#  'West Texas Intermediary Crude Oil'}

# %%
crude=commods[commods['Commodity']=='Brent Crude Oil']
crude=crude.sort_values(by='Date_Time')
crude.plot(x='Date_Time',y='Value')
# Out:
# <Axes: xlabel='Date_Time'>

# %%
consumption=pd.read_csv("Downloads\\Spring_Invitational_2024_data\\Datathon Data\\Energy Data - Consumption.csv")
consumption
# Out:
#         EIA_ID  YYYYMM       Date      Value  Column_Order  \
# 0      DFRCPUS  197301   1/1/1973   1706.943             1
# 1      DFRCPUS  197302   2/1/1973   1614.436             1
# 2      DFRCPUS  197303   3/1/1973   1140.521             1
# 3      DFRCPUS  197304   4/1/1973    824.604             1
# 4      DFRCPUS  197305   5/1/1973    676.745             1
# ...        ...     ...        ...        ...           ...
# 57562  CLTCPUS  202307   7/1/2023  47529.382            12
# 57563  CLTCPUS  202308   8/1/2023  47029.519            12
# 57564  CLTCPUS  202309   9/1/2023  37359.909            12
# 57565  CLTCPUS  202310  10/1/2023  33104.309            12
# 57566  CLTCPUS  202311  11/1/2023  32995.201            12
#
#                                              Description  \
# 0      Distillate Fuel Oil Consumed by the Residentia...
# 1      Distillate Fuel Oil Consumed by the Residentia...
# 2      Distillate Fuel Oil Consumed by the Residentia...
# 3      Distillate Fuel Oil Consumed by the Residentia...
# 4      Distillate Fuel Oil Consumed by the Residentia...
# ...                                                  ...
# 57562                            Coal Consumption, Total
# 57563                            Coal Consumption, Total
# 57564                            Coal Consumption, Total
# 57565                            Coal Consumption, Total
# 57566                            Coal Consumption, Total
#
#                            Unit          Energy Type      Energy Category  \
# 0      Thousand Barrels per Day  Distillate Fuel Oil  Distillate Fuel Oil
# 1      Thousand Barrels per Day  Distillate Fuel Oil  Distillate Fuel Oil
# 2      Thousand Barrels per Day  Distillate Fuel Oil  Distillate Fuel Oil
# 3      Thousand Barrels per Day  Distillate Fuel Oil  Distillate Fuel Oil
# 4      Thousand Barrels per Day  Distillate Fuel Oil  Distillate Fuel Oil
# ...                         ...                  ...                  ...
# 57562       Thousand Short Tons                Total                 Coal
# 57563       Thousand Short Tons                Total                 Coal
# 57564       Thousand Short Tons                Total                 Coal
# 57565       Thousand Short Tons                Total                 Coal
# 57566       Thousand Short Tons                Total                 Coal
#
#       Energy Class       Sector
# 0        Petroleum  Residential
# 1        Petroleum  Residential
# 2        Petroleum  Residential
# 3        Petroleum  Residential
# 4        Petroleum  Residential
# ...            ...          ...
# 57562         Coal          NaN
# 57563         Coal          NaN
# 57564         Coal          NaN
# 57565         Coal          NaN
# 57566         Coal          NaN
#
# [57567 rows x 11 columns]

# %%
transportation_oil=consumption[consumption["Description"]=='Total Petroleum Consumed by the Transportation Sector']

# %%
stock_energy_data=pd.read_csv("Downloads\\Spring_Invitational_2024_data\\Datathon Data\\Energy Data - Stocks.csv")
stock_energy_data
# Out:
#         EIA_ID  YYYYMM       Date           Value  Column_Order  \
# 0      COSQPUS  197301   1/1/1973  Not Applicable             1
# 1      COSQPUS  197302   2/1/1973  Not Applicable             1
# 2      COSQPUS  197303   3/1/1973  Not Applicable             1
# 3      COSQPUS  197304   4/1/1973  Not Applicable             1
# 4      COSQPUS  197305   5/1/1973  Not Applicable             1
# ...        ...     ...        ...             ...           ...
# 17548  CLPSPUS  202307   7/1/2023      146442.977             8
# 17549  CLPSPUS  202308   8/1/2023      141868.629             8
# 17550  CLPSPUS  202309   9/1/2023      139664.925             8
# 17551  CLPSPUS  202310  10/1/2023      146311.166             8
# 17552  CLPSPUS  202311  11/1/2023      154603.403             8
#
#                  Description                 Unit      Energy Type  \
# 0      Crude Oil Stocks, SPR      Million Barrels  Crude Oil - SPR
# 1      Crude Oil Stocks, SPR      Million Barrels  Crude Oil - SPR
# 2      Crude Oil Stocks, SPR      Million Barrels  Crude Oil - SPR
# 3      Crude Oil Stocks, SPR      Million Barrels  Crude Oil - SPR
# 4      Crude Oil Stocks, SPR      Million Barrels  Crude Oil - SPR
# ...                      ...                  ...              ...
# 17548     Coal Stocks, Total  Thousand Short Tons            Total
# 17549     Coal Stocks, Total  Thousand Short Tons            Total
# 17550     Coal Stocks, Total  Thousand Short Tons            Total
# 17551     Coal Stocks, Total  Thousand Short Tons            Total
# 17552     Coal Stocks, Total  Thousand Short Tons            Total
#
#       Energy Category Energy Class Sector
# 0           Crude Oil    Petroleum    NaN
# 1           Crude Oil    Petroleum    NaN
# 2           Crude Oil    Petroleum    NaN
# 3           Crude Oil    Petroleum    NaN
# 4           Crude Oil    Petroleum    NaN
# ...               ...          ...    ...
# 17548           Total         Coal    NaN
# 17549           Total         Coal    NaN
# 17550           Total         Coal    NaN
# 17551           Total         Coal    NaN
# 17552           Total         Coal    NaN
#
# [17553 rows x 11 columns]

# %%
stocks_and_etfs=pd.read_csv("Downloads\\Spring_Invitational_2024_data\\Datathon Data\\all_stocks_and_etfs.csv")
stocks_and_etfs.loc[:,'Date-Time']=pd.to_datetime(stocks_and_etfs.loc[:,'Date-Time'])

stocks_and_etfs=stocks_and_etfs.sort_values('Date-Time')
stocks_and_etfs
# Out:
#                   Date-Time     Open      High       Low     Close    Volume  \
# 144557  1999-11-01 00:00:00  136.500  137.0000  135.5625  135.5625   4006500
# 34973   1999-11-01 00:00:00    8.813    8.8750    8.7500    8.7500     20700
# 106080  1999-11-01 00:00:00   20.750   21.0600   20.5600   21.0000    209000
# 117765  1999-11-01 00:00:00   61.250   62.5600   59.7500   62.5000   2854800
# 6096    1999-11-01 00:00:00   38.250   38.8100   36.7500   38.7500   3166300
# ...                     ...      ...       ...       ...       ...       ...
# 123864  2024-01-31 00:00:00   60.440   60.6899   59.7100   59.7100    378361
# 128982  2024-02-01 00:00:00  381.400  385.1500  380.9700  385.1000   3652450
# 135084  2024-02-01 00:00:00  445.350  449.6600  444.6502  449.6600   6138360
# 138456  2024-02-01 00:00:00  484.630  489.2300  483.8000  489.2000  91891637
# 123863  2024-02-01 00:00:00   60.030   60.5200   59.8900   60.5200    420067
#
#        Ticker_Symbol
# 144557           SPY
# 34973            BPT
# 106080           EOG
# 117765           SLB
# 6096             HAL
# ...              ...
# 123864          ONEQ
# 128982           DIA
# 135084           VOO
# 138456           SPY
# 123863          ONEQ
#
# [144558 rows x 7 columns]

# %%
stocks={ticker: stocks_and_etfs[stocks_and_etfs['Ticker_Symbol']==ticker] for ticker in (set(stocks_and_etfs['Ticker_Symbol']))}
stocks['HAL'].plot(x='Date-Time',y='Close')
# Out:
# <Axes: xlabel='Date-Time'>

# %%
for ticker in set(stocks_and_etfs['Ticker_Symbol']):
    stocks[ticker].loc[:,'daily_return']=stocks[ticker].loc[:,'Close'].pct_change()
    stocks[ticker]=stocks[ticker].dropna()

# %%
stocks['HAL']
# Out:
#                 Date-Time   Open     High      Low  Close      Volume  \
# 6093  1999-11-04 00:00:00  37.56  37.6300  36.7500  36.75   1332500.0
# 6092  1999-11-05 00:00:00  37.19  37.2500  35.0000  35.56   2629800.0
# 6091  1999-11-08 00:00:00  35.56  37.7500  35.1300  37.75   1999900.0
# 6090  1999-11-09 00:00:00  38.75  39.6900  38.3800  39.38   2511500.0
# 6089  1999-11-10 00:00:00  40.13  41.0000  39.6900  39.88   2417900.0
# ...                   ...    ...      ...      ...    ...         ...
# 4     2024-01-19 00:00:00  33.43  33.9800  33.3200  33.97   8908991.0
# 3     2024-01-22 00:00:00  33.88  34.6500  33.7750  34.43  11147116.0
# 2     2024-01-23 00:00:00  34.48  35.6900  33.9400  35.30  15096866.0
# 1     2024-01-24 00:00:00  35.68  36.9500  35.4838  36.83  14397273.0
# 0     2024-01-25 00:00:00  37.08  37.2481  35.9997  37.00  11492073.0
#
#      Ticker_Symbol  daily_return
# 6093           HAL     -0.011831
# 6092           HAL     -0.032381
# 6091           HAL      0.061586
# 6090           HAL      0.043179
# 6089           HAL      0.012697
# ...            ...           ...
# 4              HAL      0.019814
# 3              HAL      0.013541
# 2              HAL      0.025269
# 1              HAL      0.043343
# 0              HAL      0.004616
#
# [6094 rows x 8 columns]

# %%
quarterly_returns=pd.DataFrame(columns=list(set(commods['Commodity']))+list(set(stocks_and_etfs['Ticker_Symbol'])),
                               index=['Q_'+str(quarter)+'_'+str(year)  for year in range(2005,2024) for quarter in range(1,5)])

for ticker in set(stocks_and_etfs['Ticker_Symbol']):
    for year in range(2005,2024):
        for quarter in range(1,5):
            data=stocks[ticker]
            data=data[data['Date-Time'].between(pd.Timestamp(year=year,month=3*quarter-2,day=1),pd.Timestamp(year=year,month=3*quarter,day=30))]
            if(data.shape[0]<1):
                continue
            start_price=data.sort_values(by='Date-Time',ascending=True).iloc[0,4]
            end_price=data.sort_values(by='Date-Time',ascending=True).iloc[-1,4]
            quarterly_returns.loc['Q_'+str(quarter)+'_'+str(year),ticker]=(end_price-start_price)/start_price
            
for ticker in set(commods['Commodity']):
    for year in range(2005,2024):
        for quarter in range(1,5):
            data=commods[commods['Commodity']==ticker]
            data=data[data['Date_Time'].between(pd.Timestamp(year=year,month=3*quarter-2,day=1),pd.Timestamp(year=year,month=3*quarter,day=30))]
            if(data.shape[0]<1):
                continue
            start_price=data.sort_values(by='Date_Time',ascending=True).iloc[0,1]
            end_price=data.sort_values(by='Date_Time',ascending=True).iloc[-1,1]
            quarterly_returns.loc['Q_'+str(quarter)+'_'+str(year),ticker]=(end_price-start_price)/start_price
            
quarterly_returns
# Out:
#          Henry Hub Natural Gas Spot Price Brent Crude Oil  \
# Q_1_2005                         0.298373        0.242454
# Q_2_2005                        -0.073976        0.022534
# Q_3_2005                         1.116976        0.093778
# Q_4_2005                        -0.303584       -0.053537
# Q_1_2006                        -0.273737        0.072183
# ...                                   ...             ...
# Q_4_2022                        -0.375887       -0.086678
# Q_1_2023                        -0.464286       -0.023768
# Q_2_2023                         0.186603       -0.131686
# Q_3_2023                         0.080645        0.286366
# Q_4_2023                        -0.044444       -0.148229
#
#          West Texas Intermediary Crude Oil       OXY       WMB      ONEQ  \
# Q_1_2005                          0.279886  0.229001  0.171925 -0.068897
# Q_2_2005                         -0.011002  0.044677 -0.003148  0.035135
# Q_3_2005                          0.120115  0.072433  0.307411  0.046122
# Q_4_2005                         -0.065789 -0.064637 -0.087795  0.017861
# Q_1_2006                          0.056885  0.096429 -0.103347  0.044886
# ...                                    ...       ...       ...       ...
# Q_4_2022                         -0.046282 -0.016703  0.117907 -0.033954
# Q_1_2023                         -0.033173  0.020803 -0.085226   0.15681
# Q_2_2023                         -0.121144 -0.097883  0.093132  0.130199
# Q_3_2023                          0.302109  0.095761  0.029645 -0.041306
# Q_4_2023                         -0.190519 -0.041573  0.057698  0.129887
#
#                BKR         E       CEO       BPT  ...        BP       CVX  \
# Q_1_2005       NaN  0.054904  0.014501  0.412434  ...  0.090686  0.144597
# Q_2_2005       NaN -0.025688  0.075612 -0.012691  ... -0.006055 -0.057157
# Q_3_2005       NaN  0.154326  0.186945   0.07617  ...  0.120512  0.136212
# Q_4_2005       NaN -0.054829 -0.048173 -0.160998  ... -0.090368 -0.119162
# Q_1_2006       NaN -0.602568  0.136002  0.037665  ...  0.050437 -0.009648
# ...            ...       ...       ...       ...  ...       ...       ...
# Q_4_2022  0.325404  0.289249       0.0 -0.109077  ...  0.160465  0.182957
# Q_1_2023       0.0 -0.028502       0.0 -0.300885  ...  0.106643  -0.06667
# Q_2_2023  0.056837 -0.022079       0.0  -0.49277  ... -0.111978 -0.074139
# Q_3_2023  0.117722  0.093525       NaN  0.540948  ...  0.077651  0.072578
# Q_4_2023 -0.010995  0.084157       NaN -0.639416  ... -0.063987 -0.104359
#
#                COP       EPD       EXC       KMI       EOG       PSX  \
# Q_1_2005  0.253478  -0.01499   0.04372       NaN -0.303231       NaN
# Q_2_2005 -0.478691   0.03237  0.118301       NaN  0.130123       NaN
# Q_3_2005   0.18291 -0.067062  0.033056       NaN   0.28078       NaN
# Q_4_2005 -0.156323 -0.059169 -0.006358       NaN -0.060443       NaN
# Q_1_2006  0.065609  0.000809 -0.026181       NaN -0.062555       NaN
# ...            ...       ...       ...       ...       ...       ...
# Q_4_2022   0.07302 -0.002069  0.123441   0.05731  0.079963  0.230551
# Q_1_2023 -0.122613  0.062732  -0.03962 -0.039423 -0.087666 -0.010294
# Q_2_2023 -0.044365  0.009192 -0.025592 -0.024915 -0.057409 -0.073171
# Q_3_2023  0.149381  0.031274 -0.079415 -0.038841  0.105144  0.256011
# Q_4_2023 -0.008796  -0.03125 -0.019394  0.091584 -0.021915  0.118636
#
#                NOV       HAL
# Q_1_2005  0.352387  0.108364
# Q_2_2005  0.010414  0.070997
# Q_3_2005  0.376569  0.424532
# Q_4_2005 -0.057426 -0.100987
# Q_1_2006 -0.028462  0.137129
# ...            ...       ...
# Q_4_2022  0.218076   0.49166
# Q_1_2023 -0.086146 -0.175252
# Q_2_2023 -0.157563 -0.032551
# Q_3_2023  0.286154  0.204282
# Q_4_2023 -0.008313 -0.091023
#
# [76 rows x 31 columns]

# %%
quarterly_returns.to_csv('quarterly_returns.csv')
quarterly_returns.corr().to_csv('Quarterly_return_correlations.csv')

# %%
stocks['CEO'][stocks['CEO']['Date-Time'].between(pd.Timestamp(year=2022,month=1,day=1),pd.Timestamp(year=2025,month=1,day=1))]
# Out:
#                   Date-Time    Open    High     Low   Close  Volume  \
# 106422  2022-01-03 00:00:00  121.76  121.76  121.76  121.76     0.0
# 106421  2022-01-04 00:00:00  121.76  121.76  121.76  121.76     0.0
# 106420  2022-01-05 00:00:00  121.76  121.76  121.76  121.76     0.0
# 106419  2022-01-06 00:00:00  121.76  121.76  121.76  121.76     0.0
# 106418  2022-01-07 00:00:00  121.76  121.76  121.76  121.76     0.0
# ...                     ...     ...     ...     ...     ...     ...
# 106085  2023-05-08 00:00:00  121.76  121.76  121.76  121.76     0.0
# 106084  2023-05-09 00:00:00  121.76  121.76  121.76  121.76     0.0
# 106083  2023-05-10 00:00:00  121.76  121.76  121.76  121.76     0.0
# 106082  2023-05-11 00:00:00  121.76  121.76  121.76  121.76     0.0
# 106081  2023-05-12 00:00:00  121.76  121.76  121.76  121.76     0.0
#
#        Ticker_Symbol  daily_return
# 106422           CEO           0.0
# 106421           CEO           0.0
# 106420           CEO           0.0
# 106419           CEO           0.0
# 106418           CEO           0.0
# ...              ...           ...
# 106085           CEO           0.0
# 106084           CEO           0.0
# 106083           CEO           0.0
# 106082           CEO           0.0
# 106081           CEO           0.0
#
# [342 rows x 8 columns]

# %%
crude=commods[commods['Commodity']=='Brent Crude Oil']
crude[crude['Date_Time'].between(pd.Timestamp(year=2023,month=1,day=1),pd.Timestamp(year=2023,month=4,day=1))]
# Out:
#                  Date_Time  Value        Commodity Commodity_Simple  \
# 17200  2023-03-31 00:00:00  79.19  Brent Crude Oil            BRENT
# 17201  2023-03-30 00:00:00  78.45  Brent Crude Oil            BRENT
# 17202  2023-03-29 00:00:00  77.51  Brent Crude Oil            BRENT
# 17203  2023-03-28 00:00:00  78.07  Brent Crude Oil            BRENT
# 17204  2023-03-27 00:00:00  76.80  Brent Crude Oil            BRENT
# ...                    ...    ...              ...              ...
# 17260  2023-01-06 00:00:00  76.41  Brent Crude Oil            BRENT
# 17261  2023-01-05 00:00:00  76.73  Brent Crude Oil            BRENT
# 17262  2023-01-04 00:00:00  75.31  Brent Crude Oil            BRENT
# 17263  2023-01-03 00:00:00  80.36  Brent Crude Oil            BRENT
# 17264  2023-01-02 00:00:00    NaN  Brent Crude Oil            BRENT
#
#                      Unit
# 17200  Dollars per Barrel
# 17201  Dollars per Barrel
# 17202  Dollars per Barrel
# 17203  Dollars per Barrel
# 17204  Dollars per Barrel
# ...                   ...
# 17260  Dollars per Barrel
# 17261  Dollars per Barrel
# 17262  Dollars per Barrel
# 17263  Dollars per Barrel
# 17264  Dollars per Barrel
#
# [65 rows x 5 columns]

# %%
stocks['FANG']
# Out:
#                 Date-Time    Open     High     Low   Close     Volume  \
# 8931  2012-10-17 00:00:00   17.70   18.070   17.50   17.70   121000.0
# 8930  2012-10-18 00:00:00   17.60   17.870   17.52   17.70   146100.0
# 8929  2012-10-19 00:00:00   17.72   17.800   17.41   17.41   298100.0
# 8928  2012-10-22 00:00:00   17.50   17.510   16.93   17.03   359800.0
# 8927  2012-10-23 00:00:00   16.85   17.295   16.75   17.13   166100.0
# ...                   ...     ...      ...     ...     ...        ...
# 6101  2024-01-19 00:00:00  149.73  151.110  149.02  151.06  1344153.0
# 6100  2024-01-22 00:00:00  151.28  153.260  150.16  151.94  2268728.0
# 6099  2024-01-23 00:00:00  150.99  153.090  150.71  151.47  1307481.0
# 6098  2024-01-24 00:00:00  152.39  153.610  151.25  153.20  1467682.0
# 6097  2024-01-25 00:00:00  154.64  156.410  152.47  156.32  2399542.0
#
#      Ticker_Symbol  daily_return
# 8931          FANG     -0.005059
# 8930          FANG      0.000000
# 8929          FANG     -0.016384
# 8928          FANG     -0.021827
# 8927          FANG      0.005872
# ...            ...           ...
# 6101          FANG      0.008815
# 6100          FANG      0.005825
# 6099          FANG     -0.003093
# 6098          FANG      0.011421
# 6097          FANG      0.020366
#
# [2835 rows x 8 columns]

# %%
quarterly_vol=pd.DataFrame(columns=list(set(commods['Commodity']))+list(set(stocks_and_etfs['Ticker_Symbol'])),
                               index=['Q_'+str(quarter)+'_'+str(year)  for year in range(2005,2024) for quarter in range(1,5)])

for ticker in set(stocks_and_etfs['Ticker_Symbol']):
    for year in range(2005,2024):
        for quarter in range(1,5):
            data=stocks[ticker]
            data=data[data['Date-Time'].between(pd.Timestamp(year=year,month=3*quarter-2,day=1),pd.Timestamp(year=year,month=3*quarter,day=30))]
            if(data.shape[0]<1):
                continue
            quarterly_vol.loc['Q_'+str(quarter)+'_'+str(year),ticker]=data['daily_return'].std()
            
for ticker in set(commods['Commodity']):
    for year in range(2005,2024):
        for quarter in range(1,5):
            data=commods[commods['Commodity']==ticker]
            data=data[data['Date_Time'].between(pd.Timestamp(year=year,month=3*quarter-2,day=1),pd.Timestamp(year=year,month=3*quarter,day=30))]
            if(data.shape[0]<1):
                continue

            quarterly_vol.loc['Q_'+str(quarter)+'_'+str(year),ticker]=data['Daily Return'].std()
            
quarterly_vol
# Out:
#          Henry Hub Natural Gas Spot Price Brent Crude Oil  \
# Q_1_2005                         0.027381         0.02134
# Q_2_2005                         0.022103        0.019285
# Q_3_2005                         0.046398        0.020491
# Q_4_2005                          0.06346        0.019252
# Q_1_2006                         0.036187        0.018309
# ...                                   ...             ...
# Q_4_2022                         0.123369        0.021556
# Q_1_2023                         0.058673        0.021183
# Q_2_2023                         0.067428        0.021305
# Q_3_2023                         0.040046        0.014676
# Q_4_2023                         0.070478        0.024963
#
#          West Texas Intermediary Crude Oil       OXY       WMB      ONEQ  \
# Q_1_2005                          0.026604  0.016174  0.020343  0.008015
# Q_2_2005                          0.023087  0.019292  0.018275  0.008009
# Q_3_2005                          0.019872  0.015146  0.018675  0.006664
# Q_4_2005                          0.018596   0.02241   0.02507  0.007948
# Q_1_2006                          0.020039  0.020786  0.018546  0.007886
# ...                                    ...       ...       ...       ...
# Q_4_2022                          0.023996  0.026572  0.017614  0.019563
# Q_1_2023                          0.021686  0.022106  0.013995  0.013477
# Q_2_2023                          0.022275  0.014547  0.013902  0.009633
# Q_3_2023                          0.014614  0.016311  0.010267  0.009676
# Q_4_2023                          0.024567  0.016593  0.011065  0.009916
#
#                BKR         E       CEO       BPT  ...        BP       CVX  \
# Q_1_2005       NaN  0.010177  0.014589  0.020185  ...  0.010011  0.012427
# Q_2_2005       NaN  0.010988  0.016798  0.028551  ...  0.010657  0.015675
# Q_3_2005       NaN  0.012287  0.022576  0.016771  ...  0.012427  0.011786
# Q_4_2005       NaN  0.013797  0.016355    0.0201  ...  0.013914  0.016148
# Q_1_2006       NaN  0.078204  0.019194  0.011793  ...  0.011749  0.013032
# ...            ...       ...       ...       ...  ...       ...       ...
# Q_4_2022  0.026466   0.02078       0.0  0.044806  ...  0.018621  0.018754
# Q_1_2023  0.021595  0.017163       0.0   0.03545  ...  0.019306  0.016648
# Q_2_2023  0.018579  0.017009       0.0  0.056855  ...  0.017118  0.014237
# Q_3_2023  0.013084  0.011693       NaN  0.045994  ...  0.011754  0.011408
# Q_4_2023  0.014669  0.011303       NaN  0.050584  ...  0.014624  0.016084
#
#                COP       EPD       EXC       KMI       EOG       PSX  \
# Q_1_2005  0.014263  0.013488  0.011946       NaN  0.066504       NaN
# Q_2_2005  0.065554  0.010939  0.012263       NaN  0.020947       NaN
# Q_3_2005  0.017666  0.011303  0.014035       NaN  0.019427       NaN
# Q_4_2005  0.023921  0.011819  0.015447       NaN  0.031235       NaN
# Q_1_2006  0.016629  0.008281  0.011839       NaN  0.025779       NaN
# ...            ...       ...       ...       ...       ...       ...
# Q_4_2022  0.025203  0.010567  0.018805  0.017692  0.025313  0.021474
# Q_1_2023   0.02247  0.009703  0.013724  0.012369  0.023662  0.022635
# Q_2_2023  0.019056  0.007101  0.011053  0.010896  0.018769  0.019439
# Q_3_2023  0.014257  0.005529  0.010185  0.010442  0.015561  0.013346
# Q_4_2023  0.016013  0.007217  0.018438  0.010982  0.015972  0.016005
#
#                NOV       HAL
# Q_1_2005  0.019358  0.019664
# Q_2_2005  0.020132  0.017852
# Q_3_2005  0.021477  0.021704
# Q_4_2005  0.026708  0.026484
# Q_1_2006  0.028199  0.023056
# ...            ...       ...
# Q_4_2022  0.030658  0.031767
# Q_1_2023  0.028143  0.027034
# Q_2_2023  0.024697  0.026439
# Q_3_2023  0.020587  0.017843
# Q_4_2023  0.021663  0.018612
#
# [76 rows x 31 columns]

# %%
quarterly_vol.to_csv('quarterly_vol.csv')
quarterly_vol.corr().to_csv('Quarterly_vol_correlations.csv')
